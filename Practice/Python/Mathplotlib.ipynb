# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Code rand about tracking time of pico code

# %%
import time
from matplotlib import pyplot

led_strip = ['green', 'blue', 'red', 'yellow']
x, y = [], []

# %%
def strobe(delay=0.5, speed_up=0.1):
    i = 1
    slow_down = True

    start_time = time.perf_counter()
    while time.perf_counter() - start_time <= 10:
        i = i % 4
        
        print(led_strip[i])
        x.append(time.perf_counter() - start_time)
        y.append(delay)
        
        time.sleep(delay)
        if slow_down:
            if delay <= 0.1:
                slow_down = False
            else:
                delay = delay * (1 - speed_up)
                speed_up = speed_up * 0.85
        else:
            if delay >= 1:
                slow_down = True
            else:
                delay = delay * (1 + speed_up)
                speed_up = speed_up * 1.15
        i += 1


delay = 1
speed_up = 0.3  # % of current delay
strobe(delay, speed_up)

print(x)
print(y)
# Out:
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# blue
# red
# yellow
# green
# ...

# %%
pyplot.legend()
pyplot.xlabel("Input")
pyplot.ylabel("Time [s]")
